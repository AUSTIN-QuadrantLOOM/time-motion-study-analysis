# %% [markdown]
# # Time motion analysis

# %% [markdown]
# ## Time & Motion Study analysis
# ## week challenge 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#  prepping the dataset of my time motion study on my day productivity

# %%
plt.style.use('ggplot')
sns.set_palette("husl")

print("Time and motion analysis -Set up complete")
print("Tracking productivity through out the day and analyze it.")
# Out:
# Time and motion analysis -Set up complete
# Tracking productivity through out the day and analyze it.
